# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import joblib

# %%
model_3 = joblib.load('SVR_Model_polynomial_of_3_degree.pkl')

# %%
model_3.predict([[8]])
# Out:
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([623.88283855])

# %% [markdown]
# #Find Unknown discharge from water level

# %%
allData = pd.read_excel('Date, all WL, some Q .xlsx', index_col = 0)
allData
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 0     1994-01-01       2.62                      7.60
# 1     1994-01-02       2.61                      7.54
# 2     1994-01-03       2.60                      7.55
# 3     1994-01-04       2.60                      7.57
# 4     1994-01-05       2.59                      7.52
# ...          ...        ...                       ...
# 10952 2023-12-27       1.55                       NaN
# 10953 2023-12-28       1.53                       NaN
# 10954 2023-12-29       1.52                       NaN
# 10955 2023-12-30       1.51                       NaN
# 10956 2023-12-31       1.48                       NaN
#
# [10957 rows x 3 columns]

# %%
missing_discharge_idx = allData[allData['MeanDailyDischarge(m3/s)'].isna()].index
allData.loc[missing_discharge_idx, 'MeanDailyDischarge(m3/s)'] = model_poly3.predict(allData.loc[missing_discharge_idx, ['AVE_WL(m)']])

# %%
allData
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 0     1994-01-01       2.62                  7.600000
# 1     1994-01-02       2.61                  7.540000
# 2     1994-01-03       2.60                  7.550000
# 3     1994-01-04       2.60                  7.570000
# 4     1994-01-05       2.59                  7.520000
# ...          ...        ...                       ...
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
#
# [10957 rows x 3 columns]

# %%
for x in range(10957) :
    element = allData.iloc[x];
    if pd.isnull(element['MeanDailyDischarge(m3/s)']) :
        wl = element['AVE_WL(m)'];
        print(wl)
        q = element['MeanDailyDischarge(m3/s)'];
        print(q)

# %%
for x in range(10957) :
    element = allData.iloc[x];
    if pd.isnull(element['MeanDailyDischarge(m3/s)']) :
        wl = element['AVE_WL(m)'];
        print(wl)
        p_q = model_poly3.predict([[wl]]);
        print(p_q)
        element['MeanDailyDischarge(m3/s)'] = p_q;
        allData.iloc[x]= element

# %%
allData
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 0     1994-01-01       2.62                  7.600000
# 1     1994-01-02       2.61                  7.540000
# 2     1994-01-03       2.60                  7.550000
# 3     1994-01-04       2.60                  7.570000
# 4     1994-01-05       2.59                  7.520000
# ...          ...        ...                       ...
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
#
# [10957 rows x 3 columns]

# %%
for x in range(10957) :
    element = allData.iloc[x];
    q = element['MeanDailyDischarge(m3/s)'];
    if q<0:
        wl = element['AVE_WL(m)'];
        p_q = model_poly3.predict([[wl]]);
        print(p_q)
        element['MeanDailyDischarge(m3/s)'] = p_q;
        allData.iloc[x]= element
# Out:
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# [-0.06542683]
# [-0.06542683]
# [-0.06542683]
# [-0.06542683]
# [-0.06542683]
# [-0.06542683]
# [-0.21022722]
# [-0.21022722]
# [-0.21022722]
# [-0.35356499]
# [-0.35356499]
# [-0.35356499]
# [-0.49544757]
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\1430028373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q;

# %%
allData
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 0     1994-01-01       2.62                  7.600000
# 1     1994-01-02       2.61                  7.540000
# 2     1994-01-03       2.60                  7.550000
# 3     1994-01-04       2.60                  7.570000
# 4     1994-01-05       2.59                  7.520000
# ...          ...        ...                       ...
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
#
# [10957 rows x 3 columns]

# %%
x10 = allData.tail(10)
x10
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 10947 2023-12-22       1.72                 -3.374190
# 10948 2023-12-23       1.67                 -3.907495
# 10949 2023-12-24       1.61                 -4.506626
# 10950 2023-12-25       1.58                 -4.789954
# 10951 2023-12-26       1.56                 -4.972962
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259

# %%
for x in range(1):
    print(x10.iloc[x]);
# Out:
# Date                        2023-12-22 00:00:00
# AVE_WL(m)                                  1.72
# MeanDailyDischarge(m3/s)               -3.37419
# Name: 10947, dtype: object

# %%
for x in range(1):
    element = x10.iloc[x];
    print(element)
    q = element['MeanDailyDischarge(m3/s)'];
    if q<0:
        print(q)
# Out:
# Date                        2023-12-22 00:00:00
# AVE_WL(m)                                  1.72
# MeanDailyDischarge(m3/s)               -3.37419
# Name: 10947, dtype: object
# -3.3741897888919885

# %%
for x in range(1):
    element = x10.iloc[x];
    q = element['MeanDailyDischarge(m3/s)'];
    wl = element['AVE_WL(m)'];
    p_q = model_poly3.predict([[wl]])
    element['MeanDailyDischarge(m3/s)'] = p_q
    print(element)
    print(wl)
    print(q)
    print(p_q)
    x10.iloc[x]= element
    print(x10)
# Out:
# Date                        2023-12-22 00:00:00
# AVE_WL(m)                                  1.72
# MeanDailyDischarge(m3/s)    -3.3741897888919885
# Name: 10947, dtype: object
# 1.72
# -3.3741897888919885
# [-3.37418979]
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 10947 2023-12-22       1.72                 -3.374190
# 10948 2023-12-23       1.67                 -3.907495
# 10949 2023-12-24       1.61                 -4.506626
# 10950 2023-12-25       1.58                 -4.789954
# 10951 2023-12-26       1.56                 -4.972962
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\MASUD RANA\AppData\Local\Temp\ipykernel_5364\2221977525.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   element['MeanDailyDischarge(m3/s)'] = p_q

# %%
x10
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 10947 2023-12-22       1.72                 -3.374190
# 10948 2023-12-23       1.67                 -3.907495
# 10949 2023-12-24       1.61                 -4.506626
# 10950 2023-12-25       1.58                 -4.789954
# 10951 2023-12-26       1.56                 -4.972962
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
