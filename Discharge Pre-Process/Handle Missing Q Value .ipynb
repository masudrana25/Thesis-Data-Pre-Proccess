# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import joblib

# %%
model_3 = joblib.load('SVR_Model_polynomial_of_3_degree.pkl')

# %%
model_3.predict([[3.5]])
# Out:
# C:\Users\MASUD RANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([43.38323806])

# %% [markdown]
# #Find Unknown discharge from water level

# %%
allData = pd.read_excel('Date, all WL, some Q .xlsx', index_col = 0)
allData
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 0     1994-01-01       2.62                      7.60
# 1     1994-01-02       2.61                      7.54
# 2     1994-01-03       2.60                      7.55
# 3     1994-01-04       2.60                      7.57
# 4     1994-01-05       2.59                      7.52
# ...          ...        ...                       ...
# 10952 2023-12-27       1.55                       NaN
# 10953 2023-12-28       1.53                       NaN
# 10954 2023-12-29       1.52                       NaN
# 10955 2023-12-30       1.51                       NaN
# 10956 2023-12-31       1.48                       NaN
#
# [10957 rows x 3 columns]

# %%
missing_discharge_idx = allData[allData['MeanDailyDischarge(m3/s)'].isna()].index
allData.loc[missing_discharge_idx, 'MeanDailyDischarge(m3/s)'] = model_poly3.predict(allData.loc[missing_discharge_idx, ['AVE_WL(m)']])

# %%
allData
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 0     1994-01-01       2.62                  7.600000
# 1     1994-01-02       2.61                  7.540000
# 2     1994-01-03       2.60                  7.550000
# 3     1994-01-04       2.60                  7.570000
# 4     1994-01-05       2.59                  7.520000
# ...          ...        ...                       ...
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
#
# [10957 rows x 3 columns]

# %%
for x in range(10957) :
    element = allData.iloc[x];
    if pd.isnull(element['MeanDailyDischarge(m3/s)']) && element['MeanDailyDischarge(m3/s)'] <0 :
        wl = element['AVE_WL(m)'];
        print(wl)
        q = element['MeanDailyDischarge(m3/s)'];
        print(q)

# %%
for x in range(10957) :
    element = allData.iloc[x];
    if pd.isnull(element['MeanDailyDischarge(m3/s)']) :
        wl = element['AVE_WL(m)'];
        print(wl)
        p_q = model_3.predict([[wl]]);
        print(p_q)
        element['MeanDailyDischarge(m3/s)'] = p_q;
        allData.iloc[x]= element
    if element['MeanDailyDischarge(m3/s)'] <0 :
        wl = element['AVE_WL(m)'];
        print(wl)
        p_q = model_3.predict([[wl]]);
        print(p_q)
        element['MeanDailyDischarge(m3/s)'] = p_q;
        allData.iloc[x]= element
# Out:
# 8.9
# [862.66445839]
# 9.11
# [925.88249641]
# 9.19
# [950.74641323]
# 9.16
# [941.37147554]
# 9.01
# [895.41088602]
# 8.81
# [836.46707104]
# 8.32
# [702.99086538]
# 7.9
# [600.42032233]
# 7.51
# [514.45224604]
# 7.16
# [444.5348448]
# 6.82
# [382.85354901]
# 6.52
# [333.29931894]
# 6.25
# [292.43117817]
# 6.0
# [257.60970933]
# 5.76
# [226.80190228]
# 5.52
# [198.45735131]
# 5.42
# [187.34972269]
# 5.61
# [208.80441006]
# 5.9
# [244.467186]
# 6.25
# [292.43117817]
# 6.22
# [288.10175925]
# 6.22
# [288.10175925]
# 6.13
# [275.36207326]
# 6.04
# [262.99103374]
# 6.15
# [278.16106569]
# 6.14
# [276.75929017]
# 6.07
# [267.07408696]
# 5.97
# [253.62051608]
# 5.81
# [233.01365325]
# 5.59
# [206.47609839]
# 5.35
# [179.81425568]
# 5.13
# [157.38661201]
# 4.91
# [136.80240119]
# 4.87
# [133.25169503]
# 4.74
# [122.10897473]
# 4.91
# [136.80240119]
# 6.56
# [339.6504554]
# 8.06
# [638.24497221]
# 7.7
# [555.24746133]
# 7.28
# [467.75687797]
# 6.9
# [396.8293833]
# 6.53
# [334.87982338]
# ...

# %%
allData
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 0     1994-01-01       2.62                  7.600000
# 1     1994-01-02       2.61                  7.540000
# 2     1994-01-03       2.60                  7.550000
# 3     1994-01-04       2.60                  7.570000
# 4     1994-01-05       2.59                  7.520000
# ...          ...        ...                       ...
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
#
# [10957 rows x 3 columns]

# %%
allData
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 0     1994-01-01       2.62                  7.600000
# 1     1994-01-02       2.61                  7.540000
# 2     1994-01-03       2.60                  7.550000
# 3     1994-01-04       2.60                  7.570000
# 4     1994-01-05       2.59                  7.520000
# ...          ...        ...                       ...
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
#
# [10957 rows x 3 columns]

# %%
x10 = allData.tail(10)
x10
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 10947 2023-12-22       1.72                       NaN
# 10948 2023-12-23       1.67                       NaN
# 10949 2023-12-24       1.61                       NaN
# 10950 2023-12-25       1.58                       NaN
# 10951 2023-12-26       1.56                       NaN
# 10952 2023-12-27       1.55                       NaN
# 10953 2023-12-28       1.53                       NaN
# 10954 2023-12-29       1.52                       NaN
# 10955 2023-12-30       1.51                       NaN
# 10956 2023-12-31       1.48                       NaN

# %%
for x in range(1):
    print(x10.iloc[x]);
# Out:
# Date                        2023-12-22 00:00:00
# AVE_WL(m)                                  1.72
# MeanDailyDischarge(m3/s)                    NaN
# Name: 10947, dtype: object

# %%
for x in range(1):
    element = x10.iloc[x];
    print(element)
    q = element['MeanDailyDischarge(m3/s)'];
    if q<0:
        print(q)
# Out:
# Date                        2023-12-22 00:00:00
# AVE_WL(m)                                  1.72
# MeanDailyDischarge(m3/s)                    NaN
# Name: 10947, dtype: object

# %%
for x in range(1):
    element = x10.iloc[x];
    q = element['MeanDailyDischarge(m3/s)'];
    wl = element['AVE_WL(m)'];
    p_q = model_3.predict([[wl]])
    element['MeanDailyDischarge(m3/s)'] = p_q
    print(element)
    print(wl)
    print(q)
    print(p_q)
    x10.iloc[x]= element
    print(x10)
# Out:
# Date                        2023-12-22 00:00:00
# AVE_WL(m)                                  1.72
# MeanDailyDischarge(m3/s)    -3.3741897888919885
# Name: 10947, dtype: object
# 1.72
# nan
# [-3.37418979]
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 10947 2023-12-22       1.72                  -3.37419
# 10948 2023-12-23       1.67                       NaN
# 10949 2023-12-24       1.61                       NaN
# 10950 2023-12-25       1.58                       NaN
# 10951 2023-12-26       1.56                       NaN
# 10952 2023-12-27       1.55                       NaN
# 10953 2023-12-28       1.53                       NaN
# 10954 2023-12-29       1.52                       NaN
# 10955 2023-12-30       1.51                       NaN
# 10956 2023-12-31       1.48                       NaN
# ...

# %%
x10
# Out:
#             Date  AVE_WL(m)  MeanDailyDischarge(m3/s)
# 10947 2023-12-22       1.72                 -3.374190
# 10948 2023-12-23       1.67                 -3.907495
# 10949 2023-12-24       1.61                 -4.506626
# 10950 2023-12-25       1.58                 -4.789954
# 10951 2023-12-26       1.56                 -4.972962
# 10952 2023-12-27       1.55                 -5.062725
# 10953 2023-12-28       1.53                 -5.238806
# 10954 2023-12-29       1.52                 -5.325139
# 10955 2023-12-30       1.51                 -5.410343
# 10956 2023-12-31       1.48                 -5.659259
